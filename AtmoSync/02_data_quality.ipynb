# %%
import os

print("Current Jupyter folder:")
print(os.getcwd())
# Out:
# Current Jupyter folder:
# C:\Users\sanni bhuwad\OneDrive\Documents\GitHub\Infotact-project\AtmoSync

# %%
print(os.listdir())
# Out:
# ['.gitignore', '.ipynb_checkpoints', '01_data_exploration.ipynb', '02_data_quality.ipynb', 'anaconda_projects', 'dashboard', 'data', 'dbt', 'docs', 'kafka', 'notebooks', 'README.md', 'requirements.txt', 'sql']

# %%
print(os.listdir(".."))
# Out:
# ['.git', '.gitattributes', '.venv', 'AtmoSync', 'README.md', 'sani', 'Sani.txt']

# %%
print(os.listdir("../data"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(os.listdir("../data"))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '../data'

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\sanni bhuwad\OneDrive\Documents\GitHub\Infotact-project\AtmoSync

# %%
print(os.getcwd())
# Out:
# C:\Users\sanni bhuwad\OneDrive\Documents\GitHub\Infotact-project\AtmoSync

# %%
import pandas as pd

df = pd.read_csv("data/cleaned/AirFreight_Cleaned.csv")

print("Shape:", df.shape)

print("\nMissing values:")
print(df.isnull().sum())

print("\nDuplicate rows:")
print(df.duplicated().sum())

print("\nData types:")
print(df.dtypes)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("data/cleaned/AirFreight_Cleaned.csv")
#       5 print("Shape:", df.shape)
#       7 print("\nMissing values:")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd

df = pd.read_csv("../data/cleaned/AirFreight_Cleaned.csv")

print("Shape:", df.shape)

print("\nMissing values:")
print(df.isnull().sum())

print("\nDuplicate rows:")
print(df.duplicated().sum())

print("\nData types:")
print(df.dtypes)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("../data/cleaned/AirFreight_Cleaned.csv")
#       5 print("Shape:", df.shape)
#       7 print("\nMissing values:")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...
