# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("../data/Cleaned_Dataset_IntermodalRail.csv")

print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 257
# Columns: 19

# %%
numeric_columns = [
    "temperature_celsius",
    "humidity_percentage",
    "vibration_level",
    "pressure_kpa",
    "exposure_duration_hours",
    "door_open_count",
    "salinity_ppt",
    "thermal_leakage_score",
    "spoilage_risk_percent",
    "remaining_shelf_life_days"
]

# %%
df[numeric_columns].describe()
# Out:
#        temperature_celsius  humidity_percentage  vibration_level  \
# count           257.000000           257.000000       257.000000
# mean              4.904280            61.494163         2.534241
# std               3.980021            15.146523         0.895864
# min              -5.000000            30.000000         0.400000
# 25%               2.300000            52.000000         1.900000
# 50%               3.900000            60.400000         2.500000
# 75%               7.500000            70.700000         3.100000
# max              23.000000            95.000000         4.900000
#
#        pressure_kpa  exposure_duration_hours  door_open_count  salinity_ppt  \
# count         257.0               257.000000            257.0         257.0
# mean            0.0               142.291051              0.0           0.0
# std             0.0                13.410157              0.0           0.0
# min             0.0               120.100000              0.0           0.0
# 25%             0.0               130.600000              0.0           0.0
# 50%             0.0               141.900000              0.0           0.0
# 75%             0.0               153.900000              0.0           0.0
# max             0.0               167.600000              0.0           0.0
#
#        thermal_leakage_score  spoilage_risk_percent  remaining_shelf_life_days
# count             257.000000             257.000000                 257.000000
# mean                4.431518              17.000389                   8.997276
# std                 2.084012              11.421739                   7.318205
# min                 0.200000               1.000000                   1.500000
# 25%                 3.000000              11.800000                   4.700000
# 50%                 4.600000              16.000000                   6.000000
# 75%                 5.800000              19.900000                  10.200000
# max                 9.500000              94.200000                  29.100000

# %%
df[numeric_columns].mean().sort_values(ascending=False)
# Out:
# exposure_duration_hours      142.291051
# humidity_percentage           61.494163
# spoilage_risk_percent         17.000389
# remaining_shelf_life_days      8.997276
# temperature_celsius            4.904280
# thermal_leakage_score          4.431518
# vibration_level                2.534241
# pressure_kpa                   0.000000
# door_open_count                0.000000
# salinity_ppt                   0.000000
# dtype: float64
