# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("../data/Cleaned_Dataset_IntermodalRail.csv")

print("Dataset loaded successfully!")
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Dataset loaded successfully!
# Rows: 257
# Columns: 19

# %%
df.head()
# Out:
#   shipment_id   transport_mode recorded_date recorded_time  \
# 0    RAIL1001  Intermodal Rail    2025-07-18         10:00
# 1    RAIL0681  Intermodal Rail    2025-03-01         10:45
# 2    RAIL0086  Intermodal Rail    2024-11-09         01:05
# 3    RAIL0432  Intermodal Rail    2024-11-30         04:35
# 4    RAIL0624  Intermodal Rail    2025-06-25         08:15
#
#      recorded_datetime origin_location destination_location       cargo_type  \
# 0  2025-07-18 10:00:00          Mumbai                Kochi          Flowers
# 1  2025-03-01 10:45:00         Kolkata                Kochi          Flowers
# 2  2024-11-09 01:05:00         Kolkata            Bengaluru             Meat
# 3  2024-11-30 04:35:00         Kolkata                Jammu  Pharmaceuticals
# 4  2025-06-25 08:15:00          Mumbai               Nagpur           Fruits
#
#    temperature_celsius  humidity_percentage  vibration_level  pressure_kpa  \
# ...

# %%
print("Humidity column information:")
print(df["humidity_percentage"].describe())
# Out:
# Humidity column information:
# count    257.000000
# mean      61.494163
# std       15.146523
# min       30.000000
# 25%       52.000000
# 50%       60.400000
# 75%       70.700000
# max       95.000000
# Name: humidity_percentage, dtype: float64

# %%
humidity_by_spoilage = df.groupby(
    "spoilage_status"
)["humidity_percentage"].mean()

print("Average Humidity by Spoilage Status:")
print(humidity_by_spoilage)
# Out:
# Average Humidity by Spoilage Status:
# spoilage_status
# At Risk    75.767857
# Fresh      60.289286
# Spoiled    78.880000
# Name: humidity_percentage, dtype: float64

# %%
plt.figure(figsize=(8, 5))

plt.scatter(
    df["humidity_percentage"],
    df["spoilage_risk_percent"]
)

plt.title("Humidity vs Spoilage Risk")
plt.xlabel("Humidity (%)")
plt.ylabel("Spoilage Risk (%)")

plt.tight_layout()
plt.show()

# %%
humidity_risk_correlation = df[
    "humidity_percentage"
].corr(
    df["spoilage_risk_percent"]
)

print(
    "Humidity vs Spoilage Risk Correlation:",
    humidity_risk_correlation
)
# Out:
# Humidity vs Spoilage Risk Correlation: 0.3731967916784638

# %%
plt.figure(figsize=(8, 5))

sns.regplot(
    data=df,
    x="humidity_percentage",
    y="spoilage_risk_percent"
)

plt.title("Humidity vs Spoilage Risk")
plt.xlabel("Humidity (%)")
plt.ylabel("Spoilage Risk (%)")

plt.tight_layout()
plt.show()
